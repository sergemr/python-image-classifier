# %%
import tensorflow as tf
import sys

member_number = int(sys.argv[1])
print("The Round 2 entry code for member {0} is:".format(member_number))

one = [member_number, int(member_number/5), int(member_number/100)]

two = [0.02, 0.05, 0.08]

a = tf.placeholder(tf.float32, shape=(3))

b = tf.placeholder(tf.float32, shape=(3))

result = tf.tensordot(a, b, 1)

with tf.Session() as sess:

   print(int(result.eval(feed_dict={a: one, b: two})))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-ab6fba8f92b4> in <module>
#      24
#      25     # convert to gray scale of each frames
# ---> 26     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      27
#      28     # Detects faces of different sizes in the input image
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
