# %%
import nltk


#Tokenizer function. You can add here different preprocesses.
def preprocess(sentence, labels):
    '''
    Task: Given a sentence apply all the required preprocessing steps
    to compute train our classifier, such as sentence splitting, 
    tokenization or sentence splitting.

    Input: Sentence in string format
    Output: Preprocessed sentence either as a list or a string
    '''
    # Place your code here
    # Keep in mind that sentence splitting affectes the number of sentences
    # and therefore, you should replicate labels to match.
    return sentence,labels

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from PIL import Image
from random import shuffle, choice
import numpy as np
import os
from google.colab import drive
import cv2 
drive.mount('/content/gdrive')

IMAGE_SIZE = 256
IMAGE_DIRECTORY = '/content/gdrive/My Drive/Colab Notebooks/Ejercicios Varios/predictions/'

def label_img(name):
    if name == 'cats': return np.array([1, 0])
    elif name == 'notcats' : return np.array([0, 1])


def prepareData(filepath):
  img_array= cv2.imread(filepath,cv2.IMREAD_GRAYSCALE)
  img_array= cv2.resize(img_array,(IMAGE_SIZE,IMAGE_SIZE))
  return img_array.reshape(-1, IMAGE_SIZE, IMAGE_SIZE, 1)
 
print('Loading model...')
model = load_model("/content/gdrive/My Drive/Colab Notebooks/Ejercicios Varios/model.h5")

print('Testing model...')
 
prediction= model.predict([prepareData('/content/gdrive/My Drive/Colab Notebooks/Ejercicios Varios/predictions/img1.png')])


print("prediction1",prediction)

prediction= model.predict([prepareData('/content/gdrive/My Drive/Colab Notebooks/Ejercicios Varios/predictions/img2.png')])


print("prediction2",prediction)


prediction= model.predict([prepareData('/content/gdrive/My Drive/Colab Notebooks/Ejercicios Varios/predictions/img3.png')])


print("prediction elefante",prediction)

prediction= model.predict([prepareData('/content/gdrive/My Drive/Colab Notebooks/Ejercicios Varios/predictions/img4.png')])


print("prediction panuelo",prediction)

prediction= model.predict([prepareData('/content/gdrive/My Drive/Colab Notebooks/Ejercicios Varios/predictions/panuelo.png')])


print("prediction panuelo",prediction[0])


prediction= model.predict([prepareData('/content/gdrive/My Drive/Colab Notebooks/Ejercicios Varios/predictions/pagato.png')])

print("prediction pagato",prediction[0])


prediction= model.predict([prepareData('/content/gdrive/My Drive/Colab Notebooks/Ejercicios Varios/predictions/paperro.png')])

print("paperro",prediction[0])
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Loading model...
# Testing model...
# 1/1 [==============================] - 0s 200ms/step
# prediction1 [[0.87136084 0.12863919]]
# 1/1 [==============================] - 0s 54ms/step
# prediction2 [[0.23596539 0.7640346 ]]
# 1/1 [==============================] - 0s 58ms/step
# prediction elefante [[0.48579714 0.5142029 ]]
# 1/1 [==============================] - 0s 67ms/step
# prediction panuelo [[0.02169966 0.9783003 ]]
# 1/1 [==============================] - 0s 56ms/step
# prediction panuelo [0.8980283  0.10197172]
# 1/1 [==============================] - 0s 57ms/step
# prediction pagato [9.996767e-01 3.233690e-04]
# 1/1 [==============================] - 0s 66ms/step
# paperro [0.00112458 0.99887544]

# %% [markdown]
# # New Section
